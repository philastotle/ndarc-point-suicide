# %% [markdown]
# # Suicide Prediction using Machine Learning.
#
# Here is the outline of the procedure:
# 1. Question
# 2. Understand the data
# 3. Manipulate the data
# 4. Fit & test models
# 5. Deploy models
#
# ## 1. Question
#
# Due to the random nature of suicidality, traditional statistical methods have reported poor performance (SOURCE). This can be attributed to the notion that no single risk factor or risk assessment approach can be directly applied to suicide prediction with great accuracy. This makes relying on few strong predictors implausible and places greater emphasis on examining a larger number of factors. This requirement of complex combinations of hundreds of factors, is not ideal for traditional statistical methods. Furthermore, traditional statistical methods require the ideal algorithm to be designed before the collection of the data (a priori) to account for certain assumptions. In contrast, DL algorithms are self-optimizing and increase their predictive performance automatically through a method called back-propagation. This use of optimization means that the DL algorithm instead, learns from the data itself giving the analyst data driven insights. This also allows DL algorithms to harness high-dimensional data where the large number of predictors allow it to learn the appropriate parameters which can be applied to future datasets. Finally, a meta-analysis by Franklin et al., (2017) found that traditional statistical methods in suicide attempts have only produced models with near chance level predictive performance, highlighting a need for more advanced data driven methods.
#
# Emerging DL research in suicidality has shown promising results compared to traditional methods. Hack et al. (2017) examined suicidality in the Grady Trauma project for those looking for primary care in large urban hospitals. Their dataset comprised of 1017 participants, split into training and test sets (80/20) both of which had stratified 16% suicide attempters. They deployed Support Vector Machines (SVMs) and least absolute shrinkage and selection operator (LASSO) models with 100 iterations of which scored an area under the curve (AUC) of 70% and 71% respectively. Walsh et al (2017) used machine learning to predict suicide attempts from electronic health records. They developed a Random Forest algorithm that utilises an ensemble of decision trees and was run for 500 iterations. Their model accurately predicted future suicide attempts with an AUC of 0.84 and found that accuracy improved from 720 days to 7 days before the suicide attempt.
#
# Walsh et al., (2017) found that “recurrent depression with psychosis, schizophrenia, and schizoaffective disorder were consistently ranked highly in importance. Age and diagnoses of dependence on opioids, sedative-hypnotics, and cannabis increased in relative importance as prediction windows shortened. Some codes that likely indicate prior suicide attempts were also consistently predictive: poisoning, the most common mechanism of prior nonfatal suicide attempts in these data; injuries by firearms; and injuries “NEC” or not elsewhere classifiable. Medication classes such as selective serotonin reuptake inhibitors (SSRIs), benzodiazepines, anilides (such as acetaminophen), and propionic acid derivatives (such as ibuprofen) appear stronger within longer prediction windows. Melatonin receptor agonists such as melatonin supplements gain relative importance closer to the suicide attempt (i.e., shorter prediction windows).”
#
# ## 2. Understand the data

# %%
import numpy as np 
import pandas as pd 
baseline = pd.read_csv("../../data/t1_beta.csv")
core = pd.read_csv("../../data/core_labels.csv")
# Out:
# /Users/philliphungerford/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (15,22,25,34,58,59,159,161,162,163,167,256,267,385,386,411,412,413,414,416,417,418,419,420,421,422,423,424,425,426,427,428,435,459,460,461,462,463,468,469,470,471,579,593,625,715,716,717,718,814,816,827,872,894,1155,1156,1158,1161,1162,1163,1165,1192,1222,1224,1226,1243,1268,1345,1439,1915,1921) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /Users/philliphungerford/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3057: DtypeWarning: Columns (26,39,40,167,169) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
baseline.head()
# Out:
#    Participant_ID  wave       today      INT_ID      phone  Postcode  \
# 0           26885     0   6/25/2013          TM  Telephone      4500
# 1           27928     0  10/25/2013  Don't Know  Telephone      3020
# 2           27112     0   8/23/2013       Other  Telephone      5052
# 3           26719     0   6/20/2013          CO  Telephone      5276
# 4           28473     0    1/7/2014  Don't Know  Telephone      4575
#
#          dob  doby  dobm  dobd  ...  OME_over90 threeorMoreCC fourorMoreCC  \
# 0  10/8/1951  1951    10     8  ...           0             0            0
# 1  3/26/1974  1974     3    26  ...           0             0            0
# 2  11/8/1960  1960    11     8  ...           0             1            0
# 3  7/15/1950  1950     7    15  ...           0             0            0
# 4  7/30/1948  1948     7    30  ...           0             1            1
#
#   Deceased1 Withdrew_self Withdrawn_all Cannabis_12m Cannabis12m_notbaseline  \
# 0        No                           0           No                      No
# 1        No                           0           No                      No
# 2        No           Yes             1           No                      No
# 3       Yes                           2           No                      No
# 4        No                           0           No                      No
#
#   Cannabisbaseline_not12m Cannabisbaseline_12m
# 0                      No                   No
# 1                      No                   No
# 2                      No                   No
# 3                      No                   No
# 4                      No                   No
#
# [5 rows x 2903 columns]

# %%
print("Shape:", baseline.shape)
# Out:
# Shape: (1514, 2903)

# %% [markdown]
# We can see that there are 1514 rows with 2903 variables for the baseline data.

# %%
# Variables we want are saved in a txt file in the current directory 
# !ls
# Out:
# Project-Assignment.ipynb model1.ipynb             model1_vars.txt

# %%
filename = "model1_vars.txt"

# using the with construct closes the file automatically when finished with it
with open(filename, "r") as file:
    variables = file.readlines()
variables = [i.strip() for i in variables]

# Now we subset the data based on the variables we are intersted in. 
model1_data = baseline[variables]

# %%
# Ideation
x = model1_data.drop('Suicidal_Thoughts_12m', axis=1)
x = x.replace(" ", np.NaN)

y = model1_data[['Suicidal_Thoughts_12m']]

# Attempts
# x = model1_data.drop('Suicide_Attempts_12m', axis=1)
# y = model1_data[['Suicide_Attempts_12m']]

# %%
to_drop1 = variables[21:32]
to_drop2 = variables[38:51]

to_drop = to_drop1 + to_drop2

# %%
list(baseline)
# Out:
# ['Participant_ID',
#  'wave',
#  'today',
#  'INT_ID',
#  'phone',
#  'Postcode',
#  'dob',
#  'doby',
#  'dobm',
#  'dobd',
#  'Actual_age',
#  'Age_group',
#  'age_under_58',
#  'sex',
#  'cob',
#  'cob_s',
#  'indig',
#  'indig_yn',
#  'edu',
#  'tertiaryedu_yn',
#  'MarritalStatus',
#  'Employ',
#  'Employ_sp',
#  'Employ_chnge_pain',
#  'Employ_before_pain',
#  'Employ_before_pain_sp',
#  'income_wk',
#  'income_wk_partner',
#  'income_lowhigh',
#  'income_range',
#  'income_yn',
#  'income_partner_lowhigh',
#  'accom',
#  'accom_sp',
#  'Live_Count',
#  'Live_Spouse',
#  'Live_Chldrn',
#  'Live_Parents',
#  'Live_Friends',
#  'Live_OthRelatives',
#  'Live_Housemates',
#  'Live_Alone',
#  'Live_Oth',
#  'relativecount',
#  'relative_yn',
#  'otherlive',
#  'otherlivewith_yn',
#  'hcm',
#  'hfeet',
#  'hinch',
#  'wkg',
#  'wpnd',
#  'hcmall',
#  'wkgall',
#  'bmi',
#  'bmicat',
#  'pain_wrk_related',
#  'complete_daily_activ',
#  'cond1',
#  'cond2',
#  'ever_Arth',
#  'ever_Back',
#  'ever_Head',
#  'ever_Visc',
#  'ever_Fibro',
#  'ever_Cmplx',
#  'ever_Shing',
#  'ever_GenPain',
#  'ever_OthPain',
#  'num_chronic_cond_ever',
#  'ever_Strk',
#  'ever_Hrtak',
#  'ever_Slpapnoea',
#  'ever_Hrtdi',
#  'ever_Hghbl',
#  'ever_Lung',
#  'ever_Diab',
#  'ever_HIV',
#  'ever_Epi',
#  'ever_Canc',
#  'ever_Oth',
#  'num_health_cond_lifetime',
#  'age_Arth',
#  'age_Back',
#  'age_Head',
#  'age_Visc',
#  'age_Fibro',
#  'age_Cmplx',
#  'age_Shing',
#  'age_GenPain',
#  'age_Othp',
#  'age_Strk',
#  'age_Hrtak',
#  'age_Slpapnoea',
#  'age_Hrtdi',
#  'age_Hghbl',
#  'age_Lung',
#  'age_Diab',
#  'age_HIV',
#  'age_Epi',
#  'age_Canc',
#  'age_Oth',
#  'Arth_12m',
#  'Back_12m',
#  'Head_12m',
#  'Visc_12m',
#  'Fibro_12m',
#  'Cmplx_12m',
#  'Shing_12m',
#  'Gen_Pain_12m',
#  'Othrp_12m',
#  'num_chronic_cond_12m',
#  'Strke_12m',
#  'Hrtak_12m',
#  'Slpapnoea_12m',
#  'Hrtdi_12m',
#  'Hghbl_12m',
#  'Lung_12m',
#  'Diab_12m',
#  'HIV_12m',
#  'Epi_12m',
#  'Canc_12m',
#  'Othr_12m',
#  'Othr_12m_sp',
#  'num_health_cond_12m',
#  'PhysCon',
#  'Arthritis12m',
#  'BackNeck12m',
#  'Headaches12m',
#  'Visceral12m',
#  'Fibromyalgia12m',
#  'ComplexRegionalPain12m',
#  'Shingles12m',
#  'OtherPain12m',
#  'Stroke12m',
#  'HeartAttack12m',
#  'SleepApnea12m',
#  'HeartDisease12m',
#  'HighBloodPressure12m',
#  'ChronicLungDisease12m',
#  'Diabetes12m',
#  'HIV12m',
#  'Epilepsy12m',
#  'Cancer12m',
#  'nolifetimecond',
#  'nocurrentcond',
#  'neuro',
#  'bpi2',
#  'bpi3',
#  'bpi4',
#  'bpi5',
#  'bpi7',
#  'bpi8a',
#  'bpi8b',
#  'bpi8c',
#  'bpi8d',
#  'bpi8e',
#  'bpi8f',
#  'bpi8g',
#  'wrst',
#  'worst_pain',
#  'least_pain',
#  'avg_pain',
#  'pain_now',
#  'BPI_PScore',
#  'BPI_PScore_five',
#  'BPI_PScore_ten',
#  'BPI_interference',
#  'BPI_PI_tot_five',
#  'BPI_PI_tot_ten',
#  'chnge',
#  'insu',
#  'bills',
#  'bilotr',
#  'sf121',
#  'sf122',
#  'sf123',
#  'sf124',
#  'sf125',
#  'sf126',
#  'sf127',
#  'sf128',
#  'sf129',
#  'sf1210',
#  'sf1211',
#  'sf1212',
#  'SF12_PCS',
#  'SF12_MCS',
#  'WG_q1',
#  'WG_q2',
#  'WG_q3',
#  'WG_q4',
#  'WG_q5',
#  'WG_q6',
#  'WG_totscore',
#  'MOS_Sleep_q1',
#  'MOS_Sleep_q2',
#  'MOS_Sleep_q3',
#  'MOS_Sleep_q4',
#  'MOS_Sleep_q5',
#  'MOS_Sleep_q6',
#  'MOS_Sleep_q7',
#  'MOS_Sleep_q8',
#  'MOS_Sleep_q9',
#  'MOS_Sleep_q10',
#  'MOS_Sleep_q11',
#  'MOS_Sleep_q12',
#  'MOS_Sleep_1score',
#  'MOS_Sleep_q4score',
#  'MOS_Sleep_q12score',
#  'MOS_Sleep_q3score',
#  'MOS_Sleep_q5score',
#  'MOS_Sleep_q6score',
#  'MOS_Sleep_q7score',
#  'MOS_Sleep_q8score',
#  'MOS_Sleep_q9score',
#  'MOS_Sleep_q10score',
#  'MOS_Sleep_q11score',
#  'SLP9',
#  'OptSlp',
#  'SLPDist',
#  'MOS_Sleep_q4a',
#  'MOS_Sleep_q12a',
#  'SLPAd',
#  'SLPDSom',
#  'SLPSNR',
#  'SLPSobH',
#  'WHO_QOL_q1',
#  'WHO_QOL_q2',
#  'falls_since_op',
#  'falls_since_op_yn',
#  'falls_unusual',
#  'falls_since_op_num',
#  'falls_NoMedicalAssist',
#  'falls_Ambul',
#  'falls_Hosp',
#  'falls_GP',
#  'falls_other',
#  'falls_other_sp',
#  'ex_rcmnd',
#  'ex_days',
#  'ex_mins',
#  'ex_in',
#  'ex_type',
#  'ex_typespecify',
#  'ex_no',
#  'ex_3mth',
#  'ex_3mth_days',
#  'ex_chnge_sincepain',
#  'ex_chnge_inc_dec',
#  'ex_chnge_inc_freq',
#  'ex_chnge_nc_dur',
#  'ex_chnge_dec_freq',
#  'ex_chnge_dec_dur',
#  'ex_chtype',
#  'ex_no3mth',
#  'ex_no3mth_specify',
#  'pseq1',
#  'pseq2',
#  'pseq3',
#  'pseq4',
#  'pseq5',
#  'pseq6',
#  'pseq7',
#  'pseq8',
#  'pseq9',
#  'pseq10',
#  'PSEQ_Score',
#  'ever_morph_IR',
#  'ever_morph_SR',
#  'ever_oxy_IR',
#  'ever_oxy_SR',
#  'ever_codeine',
#  'ever_meth_liquid',
#  'ever_meth_tablets',
#  'ever_bup_tabs_hdose',
#  'ever_bup_patch',
#  'ever_fent',
#  'ever_tram_IR',
#  'ever_tram_SR',
#  'ever_hydro_IR',
#  'ever_hydro_SR',
#  'ever_dextro',
#  'ever_oth_op',
#  'ever_oxy_naloxone',
#  'ever_bup_tabs_ldose',
#  'age_morph_IR',
#  'age_morph_SR',
#  'age_oxy_IR',
#  'age_oxy_SR',
#  'age_codeine',
#  'age_meth_liquid',
#  'age_meth_tablets',
#  'age_bup_tabs_hdose',
#  'age_bup_patch',
#  'age_fent',
#  'age_tram_IR',
#  'age_tram_SR',
#  'age_hydro_IR',
#  'age_hydro_SR',
#  'age_dextro',
#  'age_other_op',
#  'age_oxy_naloxone',
#  'age_bup_tabs_ldose',
#  'curr_morph_IR',
#  'curr_morph_SR',
#  'curr_oxy_IR',
#  'curr_oxy_SR',
#  'curr_codeine',
#  'curr_meth_liquid',
#  'curr_meth_tablets',
#  'curr_bup_tabs_hdose',
#  'curr_bup_patch',
#  'curr_fent',
#  'curr_tram_IR',
#  'curr_tram_SR',
#  'curr_hydro_IR',
#  'curr_hydro_SR',
#  'curr_dextro',
#  'curr_oth_op',
#  'curr_oxy_naloxone',
#  'curr_bup_tabs_ldose',
#  'morph_IR_days',
#  'morph_SR_days',
#  'oxy_IR_days',
#  'oxy_SR_days',
#  'codeine_days',
#  'meth_liquid_days',
#  'meth_tablets_days',
#  'bup_tabs_hdose_days',
#  'bup_patch_days',
#  'fent_days',
#  'tram_IR_days',
#  'tram_SR_days',
#  'hydro_IR_days',
#  'hydro_SR_days',
#  'dextro_days',
#  'other_op_days',
#  'oxy_naloxone_days',
#  'bup_tabs_ldose_days',
#  'other_op_sp',
#  'morph_IR_12m',
#  'morph_SR_12m',
#  'oxy_IR_12m',
#  'oxy_SR_12m',
#  'codeine_12m',
#  'meth_liquid_12m',
#  'meth_tablets_12m',
#  'bup_tabs_hdose_12m',
#  'bup_patch_12m',
#  'fent_12m',
#  'tram_IR_12m',
#  'tram_SR_12m',
#  'hydro_IR_12m',
#  'hydro_SR_12m',
#  'dextro_12m',
#  'other_op_12m',
#  'Any_Morphine_Ever',
#  'Any_Oxycodone_Ever',
#  'Any_Methadone_Ever',
#  'Any_Bup_Ever',
#  'Any_Tramadol_Ever',
#  'Any_Hydromorphone_Ever',
#  'Any_Fentanyl_Ever',
#  'Any_Dextrop_Ever',
#  'Any_Pan_Forte_Ever',
#  'Any_Morphine_12m',
#  'Any_Oxycodone_12m',
#  'Any_Methadone_12m',
#  'Any_Bup_12m',
#  'Any_Tramadol_12m',
#  'Any_Hydromorphone_12m',
#  'Any_Fentanyl_12m',
#  'Any_Dextrop_12m',
#  'Any_Pan_Forte_12m',
#  'Any_Morphine_Current',
#  'Any_Oxycodone_Current',
#  'Any_Methadone_Current',
#  'Any_Bup_Current',
#  'Any_Tramadol_Current',
#  'Any_Hydromorphone_Current',
#  'Any_Fentanyl_Current',
#  'Any_Dextrop_Current',
#  'Any_Pan_Forte_Current',
#  'S4_Current',
#  'num_lifetime_S8_opioids',
#  'num_current_s8_opioids',
#  'Current_IR_Oxycodone',
#  'Current_SR_Oxycodone',
#  'Current_SR_Morphine',
#  'Current_Fentanyl',
#  'Current_Codeine',
#  'Current_Norspan',
#  'Current_SR_Tramadol',
#  'totalopioiddoseweek',
#  'totalopioiddose',
#  'opioid200',
#  'inccur',
#  'neuro2',
#  'inc_freq',
#  'inc_severity',
#  'inc_med_freq',
#  'inc_med_sp',
#  'inc_med_effective',
#  'inc_med_dr_reco',
#  'med_type',
#  'med_type_presc_only',
#  'med_type_otc',
#  'med_type_presc_inj',
#  'sufficient',
#  'pain_duration',
#  'pain_duration_yrs',
#  'pain_duration_mths',
#  'pain_duration_wks',
#  'Time_Pain_Weeks',
#  'seedr',
#  'seedry',
#  'seedrm',
#  'seedrw',
#  'Time_Doc_Weeks',
#  'op_presc',
#  'op_presc_yrs',
#  'op_presc_mths',
#  'op_presc_wks',
#  'Time_Until_Opioids_Weeks',
#  'hlth_prof',
#  'hlth_prof_yrs',
#  'hlth_prof_mths',
#  'hlth_prof_wks',
#  'hlth_prof_num',
#  'dr_sat',
#  'brk_thru_med',
#  'incr_pain_med_7days',
#  'ofr_oth_relief',
#  'ofr_oth_relief_notuse',
#  'ofr_oth_relief_notuse_sp',
#  'travel',
#  'drtime',
#  'convenience',
#  'diff',
#  'diffa',
#  'diffb',
#  'diffc',
#  'diffd',
#  'diffe',
#  'difff',
#  'diffg',
#  'diffh',
#  'diffsp',
#  'med_effect_rest',
#  'incdnt',
#  'opidr',
#  'time',
#  'timey',
#  'timem',
#  'timew',
#  'expect',
#  'expects',
#  'presc',
#  'opcon',
#  'opcony',
#  'opconm',
#  'opconw',
#  'Time_On_Opioids_Weeks',
#  'Opioids_Less6M',
#  'Opioids_Less6aM',
#  'Opioids_Less12M',
#  'Opioids_Less12aM',
#  'op_duration',
#  'op_duration_yrs',
#  'op_duration_mths',
#  'op_duration_wks',
#  'pre_op',
#  'op_tx',
#  'op_txy',
#  'op_txm',
#  'op_txw',
#  'nausea_degree',
#  'vomiting_degree',
#  'constipation_degree',
#  'itching_degree',
#  'mental_cloud_degree',
#  'sweating_degree',
#  'fatigue_degree',
#  'drowsiness_degree',
#  'sex_dys_degree',
#  'sefct_oth_degree',
#  'sefct_oth_sp',
#  'nausea',
#  'vomiting',
#  'constipation',
#  'itching',
#  'mental_cloud',
#  'sweating',
#  'fatigue',
#  'drowsiness',
#  'sex_dys',
#  'other',
#  'adv_effects',
#  'total_adv_effects',
#  'atmeda',
#  'atmedb',
#  'atmedc',
#  'atmedd',
#  'atmede',
#  'atmedf',
#  'atmedg',
#  'atmedh',
#  'atmedi',
#  'atmedj',
#  'ever_benzo',
#  'ever_antidep',
#  'ever_antipsych',
#  'ever_anticonv',
#  'ever_antiinflam',
#  'ever_antihist',
#  'ever_antihypert',
#  'ever_anaesthetics',
#  'ever_prescmed_oth1',
#  'ever_prescmed_oth2',
#  'ever_panadol',
#  'age_benzo',
#  'age_antidep',
#  'age_antipsych',
#  'age_anticonv',
#  'age_antiinflam',
#  'age_antihist',
#  'age_antihypert',
#  'age_anaesthetics',
#  'age_prescmed_oth1',
#  'age_prescmed_oth2',
#  'age_panadol',
#  'benzo_1m',
#  'antidep_1m',
#  'antipsych_1m',
#  'anticonv_1m',
#  'antiinflam_1m',
#  'antihist_1m',
#  'antihypert_1m',
#  'anaesthetics_1m',
#  'prescmed_oth1_1m',
#  'prescmed_oth2_1m',
#  'panadol_1m',
#  'benzo_days',
#  'antidep_days',
#  'antipsych_days',
#  'anticonv_days',
#  'antiinflam_days',
#  'antihist_days',
#  'antihypert_days',
#  'anaesthetics_days',
#  'prescmed_oth1_days',
#  'prescmed_oth2_days',
#  'panadol_days',
#  'prescmed_oth_sp',
#  'otc_aspirin_1m',
#  'otc_ibuprofen_1m',
#  'otc_paracetamol_1m',
#  'otc_mersyndol_1m',
#  'otc_nurofen_1m',
#  'otc_panadine_1m',
#  'otc_diclofenac_1m',
#  'otc_naproxen_1m',
#  'otc_other_1m',
#  'otc_aspirin_days',
#  'otc_ibuprofen_days',
#  'otc_paracetamol_days',
#  'otc_mersyndol_days',
#  'otc_nurofen_days',
#  'otc_panadine_days',
#  'otc_diclofenac_days',
#  'otc_naproxen_days',
#  'otc_other_days',
#  'otc_other_sp',
#  'Current_Benzo',
#  'Current_AntiDep',
#  'Current_AntiPsychotics',
#  'Current_OTC',
#  'worse',
#  'worse_sp',
#  'worse_effect',
#  'prchs_mthd',
#  'prchs_mthd_chem_only',
#  'prchs_mthd_ph_in_pers',
#  'prchs_mthd_ol_in_pers',
#  'prchs_mthd_ph_post',
#  'prchs_mthd_ol_post',
#  'tried_ol',
#  'ol_aus_os',
#  'ol_same_effects',
#  'ol_same_effects_yes',
#  'ol_same_effects_no',
#  'ol_same_effects_sefct',
#  'ol_med',
#  'PODS_q1',
#  'PODS_q2',
#  'PODS_q3',
#  'PODS_q4',
#  'PODS_q5',
#  'PODS_q6',
#  'PODS_q7',
#  'PODS_q8',
#  'PODS_q9',
#  'PODS_q10',
#  'PODS_q11',
#  'PODS_q12',
#  'PODS_q13',
#  'PODS_q14',
#  'PODS_q15',
#  'PODS_q16',
#  'PODS_PROBS',
#  'PODS_CONC',
#  'PODS_TOT',
#  'PODS_TOTcutoff',
#  'PODS_TOTbinary',
#  'orb_1',
#  'orb_2',
#  'orb_3',
#  'orb_4',
#  'orb_5',
#  'orb_6',
#  'orb_7',
#  'orb_8',
#  'orb_9',
#  'orb_10',
#  'ORBIT_cont',
#  'ORB1',
#  'ORB2',
#  'ORB3',
#  'ORB4',
#  'ORB5',
#  'ORB6',
#  'ORB7',
#  'ORB8',
#  'ORB9',
#  'ORB10',
#  'ORBIT_Pro_num',
#  'ORBIT_Prob',
#  'physio_rcmnd',
#  'chiro_rcmnd',
#  'acup_rcmnd',
#  'psychiatrist_rcmnd',
#  'psychologist_rcmnd',
#  'couns_rcmnd',
#  'medspec_rcmnd',
#  'supgrps_rcmnd',
#  'vitamins_rcmnd',
#  'surg_rcmnd',
#  'other_rcmnd',
#  'pain_mgmtcrs_rcmnd',
#  'physio_rcvd',
#  'chiro_rcvd',
#  'acup_rcvd',
#  'psychiatrist_rcvd',
#  'psychologist_rcvd',
#  'couns_rcvd',
#  'medspec_rcvd',
#  'supgrps_rcvd',
#  'vitamins_rcvd',
#  'surg_rcvd',
#  'pain_mgmtcrs_rcvd',
#  'other_tx_rcvd',
#  'other_tx_sp',
#  'NoPhysServ',
#  'nonmed',
#  'physio_b4afta',
#  'chiro_b4afta',
#  'acup_b4afta',
#  'psychiatrist_b4afta',
#  'psychologist_b4afta',
#  'couns_b4afta',
#  'medspec_b4afta',
#  'supgrps_b4afta',
#  'vitamins_b4afta',
#  'surg_b4afta',
#  'pain_mgmtcrs_b4afta',
#  'other_tx_b4afta',
#  'physio_help',
#  'chiro_help',
#  'acup_help',
#  'psychiatrist_help',
#  'psychologist_help',
#  'couns_help',
#  'medspec_help',
#  'supgrps_help',
#  'vitamins_help',
#  'surg_help',
#  'pain_mgmtcrs_help',
#  'other_tx_help',
#  'physio_help_bin',
#  'chiro_help_bin',
#  'acup_help_bin',
#  'psychiatrist_help_bin',
#  'psychologist_help_bin',
#  'couns_help_bin',
#  'medspec_help_bin',
#  'supgrps_help_bin',
#  'vitamins_help_bin',
#  'surg_help_bin',
#  'pain_mgmtcrs_help_bin',
#  'other_tx_help_bin',
#  'physio_days',
#  'chiro_days',
#  'acup_days',
#  'psychiatrist_days',
#  'psychologist_days',
#  'couns_days',
#  'medspec_days',
#  'supgrps_days',
#  'vitamins_days',
#  'surg_days',
#  'pain_mgmtcrs_days',
#  'other_tx_days',
#  'other_tx_sp1',
#  'Private_Health',
#  'ambul_mth',
#  'emerg_mth',
#  'daypro_mth',
#  'gp_mth',
#  'spec_waitlist',
#  'spec_waitlist_duration',
#  'spec_waitlist_duration_yrs',
#  'spec_waitlist_duration_mths',
#  'spec_waitlist_duration_wks',
#  'surg_waitlist',
#  'surg_waitlist_duration',
#  'surg_waitlist_duration_yrs',
#  'surg_waitlist_duration_mths',
#  'surg_waitlist_duration_wks',
#  'new_script',
#  'new_script_filled',
#  'renew_script_ph',
#  'Seen_GP_Month',
#  'Seen_Specialist_Month',
#  'Seen_Psychiatrist_Month',
#  'Seen_Psychologist_Month',
#  'Seen_Counsellor_Month',
#  'Seen_Physio_Month',
#  'Seen_Chiro_Month',
#  'Seen_Acu_Month',
#  'Seen_Supp_groups_Month',
#  'Been_pain_man_month',
#  'Had_surgery_month',
#  'Been_Emergency_Month',
#  'Ambulance_Month',
#  'Hospital_DayProc_Month',
#  'Been_other_month',
#  'Seen_Specialist_Ever',
#  'Seen_Psychiatrist_Ever',
#  'Seen_Psychologist_Ever',
#  'Seen_Counsellor_Ever',
#  'Seen_Physio_Ever',
#  'Seen_Chiro_Ever',
#  'Seen_Acu_Ever',
#  'Seen_Supp_groups_Ever',
#  'Had_surgery_Ever',
#  'Been_pain_man_ever',
#  'Been_other_ever',
#  'BT_q1',
#  'BT_q2',
#  'BT_q3',
#  'BT_q4',
#  'BT_q5',
#  'BT_q6',
#  'BT_q7',
#  'BT_q8',
#  'BT_q9',
#  'BT_q10',
#  'BT_q11',
#  'dep_ever',
#  'ptsd_ever',
#  'anx_ever',
#  'bipol_ever',
#  'ocd_ever',
#  'schiz_ever',
#  'psychosis_ever',
#  'sud_ever',
#  'adhd_ever',
#  'pers_disorder_ever',
#  'mh_oth_ever',
#  'dep_age',
#  'ptsd_age',
#  'anx_age',
#  'bipol_age',
#  'ocd_age',
#  'schiz_age',
#  'psychosis_age',
#  'sud_age',
#  'adhd_age',
#  'pers_disorder_age',
#  'other_age',
#  'dep_12m',
#  'ptsd_12m',
#  'anx_12m',
#  'bipol_12m',
#  'ocd_12m',
#  'schiz_12m',
#  'psychosis_12m',
#  'sud_12m',
#  'adhd_12m',
#  'pers_disorder_12m',
#  'mh_oth_12m',
#  'mh_oth_sp',
#  'cond_num',
#  'PHQ1',
#  'PHQ2',
#  'PHQ3',
#  'PHQ4',
#  'PHQ5',
#  'PHQ5a',
#  'PHQ6',
#  'PHQ7',
#  'PHQ8',
#  'PHQ9',
#  'PHQ9_severity',
#  'PHQ9_severity_cutoffs',
#  'PHQ9_Mod_sev',
#  'PHQ9_critA',
#  'PHQ9_critB',
#  'MDD_PHQ9',
#  'GAD1',
#  'GAD2',
#  'GAD3',
#  'GAD4',
#  'GAD5',
#  'GAD6',
#  'GAD7',
#  'GAD_severity',
#  'GAD_severity_cutoffs',
#  'GADMod2Sev',
#  'anx_1',
#  'anx_2',
#  'anx_3',
#  'anx_4',
#  'anx_5',
#  'anx_6',
#  'anx_7',
#  'anx_8',
#  'anx_9',
#  'anx_10',
#  'anx_11',
#  'anx_12',
#  'anx_13',
#  'anx_14',
#  'anx_15',
#  'Panic_Past_Month',
#  'agor_1',
#  'agor_2',
#  'Current_Agoraphobia',
#  'bpd_1',
#  'bpd_2',
#  'bpd_3',
#  'bpd_4',
#  'bpd_5',
#  'bpd_6',
#  'bpd_7',
#  'bpd_8',
#  'bpd_9',
#  'bpd_10',
#  'bpd_15',
#  'bpd11',
#  'bpd12',
#  'bpd13',
#  'bpd14',
#  'sumbpd',
#  'Borderline',
#  'sias_1',
#  'sias_2',
#  'sias_3',
#  'sias_4',
#  'sias_5',
#  'sias_6',
#  'SIAS_SCORE',
#  'SIAS_cutoff',
#  'Suicide_Thoughts_ever',
#  'Suicide_Thoughts_age',
#  'Suicide_Thoughts_12m',
#  'Suicide_Plan_ever',
#  'Suicide_Plan_First_Age',
#  'Suicide_Attempt_Last_Age',
#  'Suicide_Plan_12m',
#  'Suicide_Attempt_12M',
#  'Suicide_Plan_Mthd_12m',
#  'Suicide_Plan_gun',
#  'Suicide_Plan_carb_monox',
#  'Suicide_Plan_cut_stab',
#  'Suicide_Plan_pills',
#  'Suicide_Plan_jump_height',
#  'Suicide_Plan_jump_train',
#  'Suicide_Plan_hang',
#  'Suicide_Plan_od_heroin',
#  'Suicide_Plan_od_op',
#  'Suicide_Plan_choke',
#  'Suicide_Plan_drown',
#  'Suicide_Plan_Other',
#  'Suicide_Attempt_ever',
#  'Suicide_Attempt_Num',
#  'Suicide_Attempt_First_Age',
#  'Suicide_Attempt_Mthd_12m',
#  'Suicide_Attempt_gun',
#  'Suicide_Attempt_carb_monox',
#  'Suicide_Attempt_cut_stab',
#  'Suicide_Attempt_pills',
#  'Suicide_Attempt_jump_hght',
#  'Suicide_Attempt_jump_train',
#  'Suicide_Attempt_hang',
#  'Suicide_Attempt_od_heroin',
#  'Suicide_Attempt_od_op',
#  'Suicide_Attempt_choke',
#  'Suicide_Attempt_drown',
#  'Suicide_Attempt_other',
#  'Suicide_Attempt_other_sp',
#  'Suicide_Statements',
#  'Suicidal_Thoughts_Ever',
#  'Suicidal_Thoughts_12m',
#  'Suicidal_Plans_Ever',
#  'Suicide_Attempts_Ever',
#  'Suicide_Attempts_12m',
#  'SelfHarm_Ever',
#  'SelfHarm_Recency',
#  'SelfHarm_Recency_yrs',
#  'SelfHarm_Recency_mths',
#  'SelfHarm_Recency_wks',
#  'SelfHarm_Num',
#  'SelfHarm_First_Age',
#  'SelfHarm_Last_Age',
#  'SelfHarm_Mthd',
#  'SelfHarm_cut_stab',
#  'SelfHarm_burn',
#  'SelfHarm_od_op',
#  'SelfHarm_od_non_op',
#  'SelfHarm_oth',
#  'SelfHarm_oth_sp',
#  'psyc1a',
#  'psyc1b',
#  'psyc1c',
#  'psyc2a',
#  'psyc2b',
#  'psyc2c',
#  'psyc3a',
#  'psyc3b',
#  'psyc3c',
#  'psyc4',
#  'ca_1',
#  'ca_2',
#  'ca_3',
#  'ca_4',
#  'ca_5',
#  'Childhood_PhysicalAb',
#  'Childhood_SexualAb',
#  'Childhood_EmotionAb',
#  'Childhood_Neglect',
#  'Childhood_Witness_Violence',
#  'ptsd',
#  'ptsd_1',
#  'ptsd_2',
#  'ptsd_3',
#  'ptsd_4',
#  'PTSDsum',
#  'PTSDcutoff3',
#  'PTSD_Past_Month',
#  'SPS_q1',
#  'SPS_q2',
#  'SPS_q3',
#  'SPS_q4',
#  'SPS_q5',
#  'SPS_q6',
#  'SPS_SCORE',
#  'SPS_cutoff',
#  'BMQ_q1',
#  'BMQ_q2',
#  'BMQ_q3',
#  'BMQ_q4',
#  'BMQ_q5',
#  'BMQ_q6',
#  'BMQ_q7',
#  'BMQ_q8',
#  'BMQ_q9',
#  'BMQ_q10',
#  'BMQ_q11',
#  'BMQ_q12',
#  'BMQ_q13',
#  'BMQ_q14',
#  'BMQ_q15',
#  'BMQ_q16',
#  'BMQ_q17',
#  'BMQ_SPECIFIC',
#  'BMQ_GENERAL',
#  'BMQ_TOTAL',
#  'BMQ_CONCERN',
#  'BMQ_NECESSITY',
#  'MHLCA_q1',
#  'MHLCA_q2',
#  'MHLCA_q3',
#  'MHLCA_q4',
#  'MHLCA_q5',
#  'MHLCA_q6',
#  'MHLCA_q7',
#  'MHLCA_q8',
#  'MHLCA_q9',
#  ...]

# %% [markdown]
# First i am going to test a model on basic features only.

# %% [markdown]
# # 3. Fit the model(s)
#
# Here we will be testing many models:
# 1. Logistic regression
# 2. Support Vector Machines
# 3. Tree models
# 4. Artificial Neural Networks
#
# ### 3.1. Logistic Regression

# %% [markdown]
# ### 3.2. Support Vector Machine

# %% [markdown]
# ### 3.3. Tree Models

# %% [markdown]
# ### 3.4. Artificial Neural Network

# %% [markdown]
# **REFERENCES**
#
# Franklin, J., Riberio, J., Fox, K., Bentley K, Kleiman, E., Huang, X., & Nock, M. (2017). 			     	Psychological Bulletin , 187-232.
#
# Hack, L., Jovanovic, T., Carter, S., Ressler, K., & Smith, A. (2017). Suicide prediction using machine 	   	learning techniques in screening clinician derived data. Biological Psychiatry, 361-361.
#
# Walsh, C., Ribeiro, J., & Franklin, J. (2017). Predicting Risk of Suicide Attempts Over Time Through   	Machine Learning. Clinical Psychological Science, 457-469.
#
# # End.
